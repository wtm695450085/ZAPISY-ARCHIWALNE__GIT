# %% [markdown]
# ## Tutorial: Linear Regression -  Tensorflow, calculation of R Square (#4)

# %% [markdown]
# We continue to learn how to build multiple linear regression models. This time we will build a model using the Tensorflow library. As before, the data file: AirQ_filled2.csv comes from previous episodes of this cycle.

# %%
import tensorflow as tf
import pandas as pd

df = pd.read_csv('c:/TF/AirQ_filled2.csv', usecols=['CO(GT)','PT08.S1(CO)','C6H6(GT)','PT08.S2(NMHC)','NOx(GT)','PT08.S3(NOx)','NO2(GT)','PT08.S4(NO2)','PT08.S5(O3)','T','RH', 'AH'
        ,'Month','Weekday','Hours'])
df.head(3)
# Out:
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:496: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:497: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\envs\OLD_TF\lib\site-packages\tensorflow\python\framework\dtypes.py:502: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#    CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  \
# 0     2.6       1360.0      11.9         1046.0    166.0        1056.0
# 1     2.0       1292.0       9.4          955.0    103.0        1174.0
# 2     2.2       1402.0       9.0          939.0    131.0        1140.0
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  Month  Weekday  \
# 0    113.0        1692.0       1268.0  13.6  48.9  0.7578      3        2
# 1     92.0        1559.0        972.0  13.3  47.7  0.7255      3        2
# 2    114.0        1555.0       1074.0  11.9  54.0  0.7502      3        2
#
#    Hours
# 0     18
# 1     19
# 2     20

# %% [markdown]
# ### <span style="color:darkBlue">Step 1: Convert Data</span>
#
# We convert numeric variables in the correct Tensorflow format. Tensorflow provides a continuous variable conversion method: tf.feature_column.numeric_column ().
#
# <span style="color:Blue">Separation of a column into an independent variable and a dependent variable.</span>

# %%
df.columns
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)',
#        'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH',
#        'AH', 'Month', 'Weekday', 'Hours'],
#       dtype='object')

# %%
df.columns = ['CO_GT', 'PT08.S1_CO', 'C6H6_GT', 'PT08.S2_NMHC',
       'NOx_GT', 'PT08.S3_NOx', 'NO2_GT', 'PT08.S4_NO2', 'PT08.S5_O3',
       'T', 'RH', 'AH', 'Month', 'Weekday', 'Hours']

# %%
df.dtypes
# Out:
# CO_GT           float64
# PT08.S1_CO      float64
# C6H6_GT         float64
# PT08.S2_NMHC    float64
# NOx_GT          float64
# PT08.S3_NOx     float64
# NO2_GT          float64
# PT08.S4_NO2     float64
# PT08.S5_O3      float64
# T               float64
# RH              float64
# AH              float64
# Month             int64
# Weekday           int64
# Hours             int64
# dtype: object

# %%
FEATURES = ['PT08.S1_CO', 'C6H6_GT', 'PT08.S2_NMHC',
       'NOx_GT', 'PT08.S3_NOx', 'NO2_GT', 'PT08.S4_NO2', 'PT08.S5_O3',
       'T', 'RH', 'AH', 'Month', 'Weekday', 'Hours']
LABEL = 'CO_GT'

# %%
PKS = [tf.feature_column.numeric_column(k) for k in FEATURES]
PKS
# Out:
# [_NumericColumn(key='PT08.S1_CO', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='C6H6_GT', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PT08.S2_NMHC', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='NOx_GT', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PT08.S3_NOx', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='NO2_GT', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PT08.S4_NO2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PT08.S5_O3', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='T', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='RH', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='AH', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Month', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Weekday', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Hours', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ### <span style="color:darkBlue">Step 2: Defining the estimator</span>
#
# Tensorflow will automatically create a file called "Air" in your working directory. You must use this path to access Tensorboard. The estimator applies to independent variables.

# %%
estimator = tf.estimator.LinearRegressor(    
        feature_columns=PKS,   
        model_dir="Air")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'Air', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000017E850F7CC0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# To instruct Tensorflow how to feed the model, you can use pandas_input_fn. This object needs 5 parameters: x: function data y: label data batch_size: batch. Default 128 num_epoch: by default number of epochs 1 random: Random or not data. Default None

# %%
def get_input_fn(data_set, num_epochs=None, n_batch = 128, shuffle=True):    
         return tf.estimator.inputs.pandas_input_fn(       
         x=pd.DataFrame({k: data_set[k].values for k in FEATURES}),       
         y = pd.Series(data_set[LABEL].values),       
         batch_size=n_batch,          
         num_epochs=num_epochs,       
         shuffle=shuffle)

# %% [markdown]
# ### <span style="color:darkBlue">Step 3: Model training</span>
#
#     - To feed the model you can use the function created above: get_input_fn.
#     - Then you instruct the model to iterate 1000 times.
#     - Remember that you do not specify the number of epochs (num_epochs).
#     - It is better to set the number of epochs to none and define the number of iterations.
#
#   To test the model, we must divide the data set into a test set and a training set.

# %%
df_train=df.sample(frac=0.8,random_state=200)
df_test=df.drop(df_train.index)
print(df_train.shape, df_test.shape)
# Out:
# (7486, 15) (1871, 15)

# %%
estimator.train(input_fn=get_input_fn(df_train,                                       
                                           num_epochs=None,                                      
                                           n_batch = 128,                                      
                                           shuffle=False),                                      
                                           steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from Air\model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into Air\model.ckpt.
# INFO:tensorflow:loss = 27.90989, step = 10001
# INFO:tensorflow:global_step/sec: 231.067
# INFO:tensorflow:loss = 19.266008, step = 10101 (0.443 sec)
# INFO:tensorflow:global_step/sec: 250.047
# INFO:tensorflow:loss = 21.174185, step = 10201 (0.389 sec)
# INFO:tensorflow:global_step/sec: 244.378
# INFO:tensorflow:loss = 26.823406, step = 10301 (0.409 sec)
# INFO:tensorflow:global_step/sec: 263.037
# INFO:tensorflow:loss = 16.690845, step = 10401 (0.380 sec)
# INFO:tensorflow:global_step/sec: 250.698
# INFO:tensorflow:loss = 24.08421, step = 10501 (0.399 sec)
# INFO:tensorflow:global_step/sec: 254.447
# INFO:tensorflow:loss = 16.630123, step = 10601 (0.406 sec)
# INFO:tensorflow:global_step/sec: 248.812
# INFO:tensorflow:loss = 25.998842, step = 10701 (0.389 sec)
# INFO:tensorflow:global_step/sec: 269.371
# INFO:tensorflow:loss = 31.432064, step = 10801 (0.387 sec)
# INFO:tensorflow:global_step/sec: 255.634
# INFO:tensorflow:loss = 22.70269, step = 10901 (0.391 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into Air\model.ckpt.
# INFO:tensorflow:Loss for final step: 24.21025.

# %% [markdown]
# ## <span style="color:darkblue">Step 4. Model evaluation</span>
#
# To enter a test set, use the following code:

# %%
ev = estimator.evaluate(    
          input_fn=get_input_fn(df_test,                          
          num_epochs=1,                          
          n_batch = 356,                          
          shuffle=False))
# Out:
# INFO:tensorflow:Starting evaluation at 2019-11-28-13:40:17
# INFO:tensorflow:Restoring parameters from Air\model.ckpt-11000
# INFO:tensorflow:Finished evaluation at 2019-11-28-13:40:17
# INFO:tensorflow:Saving dict for global step 11000: average_loss = 0.18934268, global_step = 11000, loss = 59.04336

# %% [markdown]
# Print the loss using by the code below:

# %%
loss_score = ev["loss"]
print("Loss: {0:f}".format(loss_score))
# Out:
# Loss: 59.043362

# %% [markdown]
# # <span style="color:#4c1130">Calculation of R Square parameter using Tensorflow</span>

# %% [markdown]
# ### I make a prediction on a test set

# %%
y = estimator.predict(    
         input_fn=get_input_fn(df_test,                          
         num_epochs=1,                          
         n_batch = 256,                          
         shuffle=False))

# %%
import itertools

predictions = list(p["predictions"] for p in itertools.islice(y, 1871))
#print("Predictions: {}".format(str(predictions)))
# Out:
# INFO:tensorflow:Restoring parameters from Air\model.ckpt-11000

# %%
predictions
# Out:
# [array([2.2904341], dtype=float32),
#  array([1.4195127], dtype=float32),
#  array([0.9917113], dtype=float32),
#  array([1.4134599], dtype=float32),
#  array([1.471673], dtype=float32),
#  array([2.7519426], dtype=float32),
#  array([2.940657], dtype=float32),
#  array([1.2862953], dtype=float32),
#  array([1.3224933], dtype=float32),
#  array([3.0704021], dtype=float32),
#  array([2.8271983], dtype=float32),
#  array([3.867299], dtype=float32),
#  array([5.885076], dtype=float32),
#  array([2.2754772], dtype=float32),
#  array([1.4783571], dtype=float32),
#  array([3.3553271], dtype=float32),
#  array([3.0452268], dtype=float32),
#  array([2.7399206], dtype=float32),
#  array([4.6770415], dtype=float32),
#  array([3.1906075], dtype=float32),
#  array([0.5753575], dtype=float32),
#  array([0.75079066], dtype=float32),
#  array([1.0355924], dtype=float32),
#  array([4.0292635], dtype=float32),
#  array([3.8016758], dtype=float32),
#  array([3.1854193], dtype=float32),
#  array([0.68301827], dtype=float32),
#  array([2.7589178], dtype=float32),
#  array([6.466273], dtype=float32),
#  array([5.046124], dtype=float32),
#  array([3.1789286], dtype=float32),
#  array([1.781652], dtype=float32),
#  array([1.3143581], dtype=float32),
#  array([0.83832365], dtype=float32),
#  array([2.5561447], dtype=float32),
#  array([4.8233523], dtype=float32),
#  array([3.0344853], dtype=float32),
#  array([0.8646746], dtype=float32),
#  array([2.9195652], dtype=float32),
#  array([3.0918183], dtype=float32),
#  array([4.0698285], dtype=float32),
#  array([3.863769], dtype=float32),
#  array([2.1419969], dtype=float32),
#  array([1.0901375], dtype=float32),
#  array([3.5392985], dtype=float32),
#  array([2.4009166], dtype=float32),
#  array([2.8897052], dtype=float32),
#  array([3.411408], dtype=float32),
#  array([1.7559586], dtype=float32),
#  array([3.0747113], dtype=float32),
#  array([2.098154], dtype=float32),
#  array([0.82973903], dtype=float32),
#  array([-0.0303503], dtype=float32),
#  array([2.8779633], dtype=float32),
#  array([2.7544298], dtype=float32),
#  array([1.8519044], dtype=float32),
#  array([1.4793736], dtype=float32),
#  array([1.2532313], dtype=float32),
#  array([1.2098429], dtype=float32),
#  array([0.4885053], dtype=float32),
#  array([0.33943284], dtype=float32),
#  array([2.0091887], dtype=float32),
#  array([3.466254], dtype=float32),
#  array([3.8976512], dtype=float32),
#  array([2.4916697], dtype=float32),
#  array([2.393389], dtype=float32),
#  array([0.813953], dtype=float32),
#  array([2.4096189], dtype=float32),
#  array([2.7706006], dtype=float32),
#  array([1.8008243], dtype=float32),
#  array([2.1749105], dtype=float32),
#  array([1.9999294], dtype=float32),
#  array([1.9602013], dtype=float32),
#  array([2.1792994], dtype=float32),
#  array([1.0705328], dtype=float32),
#  array([1.0532345], dtype=float32),
#  array([0.4026578], dtype=float32),
#  array([1.5936644], dtype=float32),
#  array([1.6506209], dtype=float32),
#  array([1.4705824], dtype=float32),
#  array([1.4140408], dtype=float32),
#  array([1.9086331], dtype=float32),
#  array([2.0708742], dtype=float32),
#  array([0.83423823], dtype=float32),
#  array([0.6893924], dtype=float32),
#  array([1.5523638], dtype=float32),
#  array([1.9342153], dtype=float32),
#  array([2.3264472], dtype=float32),
#  array([0.8550148], dtype=float32),
#  array([2.1080718], dtype=float32),
#  array([2.3627877], dtype=float32),
#  array([2.518602], dtype=float32),
#  array([1.4152904], dtype=float32),
#  array([1.1316373], dtype=float32),
#  array([1.9356787], dtype=float32),
#  array([5.785367], dtype=float32),
#  array([4.1415854], dtype=float32),
#  array([1.7315837], dtype=float32),
#  array([2.6435518], dtype=float32),
#  array([2.7715325], dtype=float32),
#  array([2.6991568], dtype=float32),
#  array([4.647268], dtype=float32),
#  array([2.932753], dtype=float32),
#  array([0.89095634], dtype=float32),
#  array([3.1305285], dtype=float32),
#  array([2.3312593], dtype=float32),
#  array([3.071854], dtype=float32),
#  array([4.699164], dtype=float32),
#  array([2.110075], dtype=float32),
#  array([0.9892289], dtype=float32),
#  array([1.2014885], dtype=float32),
#  array([2.1266057], dtype=float32),
#  array([2.2080152], dtype=float32),
#  array([2.835823], dtype=float32),
#  array([1.4109471], dtype=float32),
#  array([0.9744153], dtype=float32),
#  array([4.8938127], dtype=float32),
#  array([3.3829663], dtype=float32),
#  array([2.134839], dtype=float32),
#  array([0.7879383], dtype=float32),
#  array([0.5850801], dtype=float32),
#  array([2.9102216], dtype=float32),
#  array([3.086039], dtype=float32),
#  array([0.69071877], dtype=float32),
#  array([0.18472998], dtype=float32),
#  array([2.7660463], dtype=float32),
#  array([3.1288075], dtype=float32),
#  array([1.517092], dtype=float32),
#  array([1.6706876], dtype=float32),
#  array([1.5426283], dtype=float32),
#  array([1.8689629], dtype=float32),
#  array([1.8573358], dtype=float32),
#  array([1.9050127], dtype=float32),
#  array([1.8414214], dtype=float32),
#  array([2.0376077], dtype=float32),
#  array([1.9968758], dtype=float32),
#  array([1.8027763], dtype=float32),
#  array([1.5331185], dtype=float32),
#  array([1.9726132], dtype=float32),
#  array([1.291136], dtype=float32),
#  array([0.9332365], dtype=float32),
#  array([1.0123768], dtype=float32),
#  array([1.0508232], dtype=float32),
#  array([0.9733463], dtype=float32),
#  array([0.6099342], dtype=float32),
#  array([1.1540895], dtype=float32),
#  array([1.1893405], dtype=float32),
#  array([0.86438316], dtype=float32),
#  array([0.4341547], dtype=float32),
#  array([1.8266513], dtype=float32),
#  array([1.8147647], dtype=float32),
#  array([4.241465], dtype=float32),
#  array([2.7010531], dtype=float32),
#  array([2.8672311], dtype=float32),
#  array([0.6639576], dtype=float32),
#  array([4.043116], dtype=float32),
#  array([4.305127], dtype=float32),
#  array([4.4972], dtype=float32),
#  array([5.987199], dtype=float32),
#  array([2.2596898], dtype=float32),
#  array([0.797895], dtype=float32),
#  array([0.98379046], dtype=float32),
#  array([2.303831], dtype=float32),
#  array([2.3073964], dtype=float32),
#  array([3.4966726], dtype=float32),
#  array([3.9018369], dtype=float32),
#  array([1.8249042], dtype=float32),
#  array([1.0217783], dtype=float32),
#  array([1.8673329], dtype=float32),
#  array([2.0018885], dtype=float32),
#  array([1.2846329], dtype=float32),
#  array([1.7335545], dtype=float32),
#  array([1.43964], dtype=float32),
#  array([1.9431471], dtype=float32),
#  array([0.8150239], dtype=float32),
#  array([1.741921], dtype=float32),
#  array([1.1024103], dtype=float32),
#  array([0.8654898], dtype=float32),
#  array([0.6054179], dtype=float32),
#  array([1.9328833], dtype=float32),
#  array([1.6224344], dtype=float32),
#  array([1.6959083], dtype=float32),
#  array([3.661971], dtype=float32),
#  array([1.7461376], dtype=float32),
#  array([1.8273584], dtype=float32),
#  array([1.1477997], dtype=float32),
#  array([0.80859727], dtype=float32),
#  array([2.3207037], dtype=float32),
#  array([2.0190673], dtype=float32),
#  array([2.3051033], dtype=float32),
#  array([4.697051], dtype=float32),
#  array([5.647171], dtype=float32),
#  array([0.8242163], dtype=float32),
#  array([4.261741], dtype=float32),
#  array([4.3355823], dtype=float32),
#  array([3.5309992], dtype=float32),
#  array([4.5853353], dtype=float32),
#  array([3.8750296], dtype=float32),
#  array([2.6595106], dtype=float32),
#  array([1.963249], dtype=float32),
#  array([0.8092183], dtype=float32),
#  array([0.27052438], dtype=float32),
#  array([0.7519834], dtype=float32),
#  array([0.6510158], dtype=float32),
#  array([1.1775835], dtype=float32),
#  array([2.001943], dtype=float32),
#  array([0.18676807], dtype=float32),
#  array([1.4195979], dtype=float32),
#  array([1.6657784], dtype=float32),
#  array([0.6410345], dtype=float32),
#  array([0.9768651], dtype=float32),
#  array([4.32481], dtype=float32),
#  array([1.8637958], dtype=float32),
#  array([1.8540816], dtype=float32),
#  array([3.139664], dtype=float32),
#  array([3.278608], dtype=float32),
#  array([2.5569234], dtype=float32),
#  array([0.6359319], dtype=float32),
#  array([3.6107602], dtype=float32),
#  array([3.5360956], dtype=float32),
#  array([4.871655], dtype=float32),
#  array([4.501004], dtype=float32),
#  array([1.8894767], dtype=float32),
#  array([1.7202177], dtype=float32),
#  array([1.2360561], dtype=float32),
#  array([0.67274344], dtype=float32),
#  array([1.1452334], dtype=float32),
#  array([5.298881], dtype=float32),
#  array([3.953755], dtype=float32),
#  array([3.860598], dtype=float32),
#  array([3.5970106], dtype=float32),
#  array([3.3814263], dtype=float32),
#  array([3.7267027], dtype=float32),
#  array([1.7599449], dtype=float32),
#  array([2.2581372], dtype=float32),
#  array([2.3139908], dtype=float32),
#  array([3.0513158], dtype=float32),
#  array([1.5984023], dtype=float32),
#  array([1.1290988], dtype=float32),
#  array([1.505525], dtype=float32),
#  array([2.9691339], dtype=float32),
#  array([4.1380916], dtype=float32),
#  array([2.678059], dtype=float32),
#  array([2.8793745], dtype=float32),
#  array([2.7446685], dtype=float32),
#  array([1.6941228], dtype=float32),
#  array([3.775039], dtype=float32),
#  array([3.9633222], dtype=float32),
#  array([0.5396735], dtype=float32),
#  array([1.5708241], dtype=float32),
#  array([4.011679], dtype=float32),
#  array([2.881592], dtype=float32),
#  array([1.2433776], dtype=float32),
#  array([2.5088096], dtype=float32),
#  array([2.9840298], dtype=float32),
#  array([1.826118], dtype=float32),
#  array([0.5945964], dtype=float32),
#  array([2.0539107], dtype=float32),
#  array([1.8076622], dtype=float32),
#  array([1.6809814], dtype=float32),
#  array([0.6150927], dtype=float32),
#  array([1.6270561], dtype=float32),
#  array([0.6772328], dtype=float32),
#  array([1.1328309], dtype=float32),
#  array([1.5834949], dtype=float32),
#  array([2.244759], dtype=float32),
#  array([0.33340913], dtype=float32),
#  array([0.5062675], dtype=float32),
#  array([5.4168906], dtype=float32),
#  array([3.892551], dtype=float32),
#  array([2.6888], dtype=float32),
#  array([2.6152852], dtype=float32),
#  array([3.142117], dtype=float32),
#  array([0.3904891], dtype=float32),
#  array([3.3728242], dtype=float32),
#  array([2.446887], dtype=float32),
#  array([2.9350355], dtype=float32),
#  array([1.8753281], dtype=float32),
#  array([1.2039299], dtype=float32),
#  array([0.8553297], dtype=float32),
#  array([0.71280223], dtype=float32),
#  array([3.0194001], dtype=float32),
#  array([2.1500645], dtype=float32),
#  array([1.6864929], dtype=float32),
#  array([0.34257168], dtype=float32),
#  array([2.3596811], dtype=float32),
#  array([2.14133], dtype=float32),
#  array([4.937047], dtype=float32),
#  array([1.9297763], dtype=float32),
#  array([2.0185359], dtype=float32),
#  array([2.0943928], dtype=float32),
#  array([3.023369], dtype=float32),
#  array([2.0187998], dtype=float32),
#  array([1.280459], dtype=float32),
#  array([2.2753346], dtype=float32),
#  array([2.1416435], dtype=float32),
#  array([1.5878749], dtype=float32),
#  array([0.5821696], dtype=float32),
#  array([1.5363239], dtype=float32),
#  array([1.410404], dtype=float32),
#  array([0.8817283], dtype=float32),
#  array([0.40053523], dtype=float32),
#  array([2.4928474], dtype=float32),
#  array([0.3366376], dtype=float32),
#  array([1.5682609], dtype=float32),
#  array([2.2222824], dtype=float32),
#  array([3.0045118], dtype=float32),
#  array([4.360746], dtype=float32),
#  array([3.0260515], dtype=float32),
#  array([2.5176258], dtype=float32),
#  array([0.63440377], dtype=float32),
#  array([3.8547235], dtype=float32),
#  array([2.6477635], dtype=float32),
#  array([2.44276], dtype=float32),
#  array([2.5053735], dtype=float32),
#  array([3.7653549], dtype=float32),
#  array([2.11771], dtype=float32),
#  array([1.8221376], dtype=float32),
#  array([0.52940035], dtype=float32),
#  array([3.7987092], dtype=float32),
#  array([5.5749326], dtype=float32),
#  array([2.8682332], dtype=float32),
#  array([3.706054], dtype=float32),
#  array([3.782782], dtype=float32),
#  array([0.943226], dtype=float32),
#  array([0.748783], dtype=float32),
#  array([1.5829477], dtype=float32),
#  array([2.2736783], dtype=float32),
#  array([2.138954], dtype=float32),
#  array([3.0542362], dtype=float32),
#  array([0.9808884], dtype=float32),
#  array([2.5517685], dtype=float32),
#  array([2.4594076], dtype=float32),
#  array([1.2189941], dtype=float32),
#  array([1.5266862], dtype=float32),
#  array([0.05554104], dtype=float32),
#  array([2.063158], dtype=float32),
#  array([2.4869254], dtype=float32),
#  array([0.2612537], dtype=float32),
#  array([2.3111362], dtype=float32),
#  array([2.054067], dtype=float32),
#  array([2.5285244], dtype=float32),
#  array([4.0279994], dtype=float32),
#  array([4.748059], dtype=float32),
#  array([2.3560085], dtype=float32),
#  array([1.9876475], dtype=float32),
#  array([3.283031], dtype=float32),
#  array([2.370753], dtype=float32),
#  array([2.5275578], dtype=float32),
#  array([0.44904944], dtype=float32),
#  array([1.5834723], dtype=float32),
#  array([3.4670954], dtype=float32),
#  array([1.6226081], dtype=float32),
#  array([0.63556695], dtype=float32),
#  array([2.6852129], dtype=float32),
#  array([2.1385925], dtype=float32),
#  array([1.5632329], dtype=float32),
#  array([0.91587436], dtype=float32),
#  array([2.6740823], dtype=float32),
#  array([2.4878416], dtype=float32),
#  array([0.63499916], dtype=float32),
#  array([0.62906474], dtype=float32),
#  array([0.732759], dtype=float32),
#  array([0.92107624], dtype=float32),
#  array([1.0106192], dtype=float32),
#  array([2.3653264], dtype=float32),
#  array([2.9585295], dtype=float32),
#  array([0.48563528], dtype=float32),
#  array([2.540512], dtype=float32),
#  array([2.5728626], dtype=float32),
#  array([2.4886446], dtype=float32),
#  array([3.1962295], dtype=float32),
#  array([2.9255414], dtype=float32),
#  array([1.7701344], dtype=float32),
#  array([0.9429248], dtype=float32),
#  array([2.7807956], dtype=float32),
#  array([1.4370277], dtype=float32),
#  array([0.84167683], dtype=float32),
#  array([0.24522857], dtype=float32),
#  array([3.6723037], dtype=float32),
#  array([1.8639292], dtype=float32),
#  array([1.851813], dtype=float32),
#  array([1.775257], dtype=float32),
#  array([0.96424854], dtype=float32),
#  array([0.93372184], dtype=float32),
#  array([1.2668002], dtype=float32),
#  array([2.076168], dtype=float32),
#  array([1.6206529], dtype=float32),
#  array([1.0114766], dtype=float32),
#  array([1.4029086], dtype=float32),
#  array([1.6665723], dtype=float32),
#  array([0.44064057], dtype=float32),
#  array([0.73801345], dtype=float32),
#  array([1.6711899], dtype=float32),
#  array([0.4520291], dtype=float32),
#  array([0.46702236], dtype=float32),
#  array([2.9673066], dtype=float32),
#  array([2.5014713], dtype=float32),
#  array([2.5852292], dtype=float32),
#  array([2.4820971], dtype=float32),
#  array([1.8014017], dtype=float32),
#  array([1.3585465], dtype=float32),
#  array([3.4945612], dtype=float32),
#  array([2.7107935], dtype=float32),
#  array([2.6659863], dtype=float32),
#  array([2.87777], dtype=float32),
#  array([2.1245418], dtype=float32),
#  array([1.6596208], dtype=float32),
#  array([0.87377685], dtype=float32),
#  array([4.0097632], dtype=float32),
#  array([3.2386417], dtype=float32),
#  array([3.4055138], dtype=float32),
#  array([2.9903085], dtype=float32),
#  array([2.2100008], dtype=float32),
#  array([3.2663639], dtype=float32),
#  array([2.2319255], dtype=float32),
#  array([1.1614068], dtype=float32),
#  array([4.2777123], dtype=float32),
#  array([2.4339757], dtype=float32),
#  array([2.2207303], dtype=float32),
#  array([4.1055274], dtype=float32),
#  array([2.689881], dtype=float32),
#  array([0.7159311], dtype=float32),
#  array([0.5967155], dtype=float32),
#  array([1.5205104], dtype=float32),
#  array([2.4843566], dtype=float32),
#  array([3.3747077], dtype=float32),
#  array([2.7871854], dtype=float32),
#  array([2.0920908], dtype=float32),
#  array([1.2762592], dtype=float32),
#  array([2.5227447], dtype=float32),
#  array([1.8388726], dtype=float32),
#  array([0.8691055], dtype=float32),
#  array([0.19649933], dtype=float32),
#  array([0.64095396], dtype=float32),
#  array([0.6860624], dtype=float32),
#  array([0.7595658], dtype=float32),
#  array([0.44122896], dtype=float32),
#  array([1.2220902], dtype=float32),
#  array([1.4943619], dtype=float32),
#  array([1.1140056], dtype=float32),
#  array([0.226597], dtype=float32),
#  array([0.7188161], dtype=float32),
#  array([1.6113896], dtype=float32),
#  array([4.239774], dtype=float32),
#  array([3.0751896], dtype=float32),
#  array([3.4589472], dtype=float32),
#  array([2.802142], dtype=float32),
#  array([2.2172718], dtype=float32),
#  array([2.1505182], dtype=float32),
#  array([0.56232744], dtype=float32),
#  array([1.4210694], dtype=float32),
#  array([3.3673658], dtype=float32),
#  array([2.8841789], dtype=float32),
#  array([2.210266], dtype=float32),
#  array([2.2491984], dtype=float32),
#  array([2.5432954], dtype=float32),
#  array([0.8778456], dtype=float32),
#  array([0.71616095], dtype=float32),
#  array([1.8332256], dtype=float32),
#  array([2.7588305], dtype=float32),
#  array([1.8829712], dtype=float32),
#  array([0.7282937], dtype=float32),
#  array([0.82473564], dtype=float32),
#  array([1.7696285], dtype=float32),
#  array([1.7535007], dtype=float32),
#  array([1.9197856], dtype=float32),
#  array([1.6807878], dtype=float32),
#  array([1.6809825], dtype=float32),
#  array([1.6777997], dtype=float32),
#  array([1.6948826], dtype=float32),
#  array([1.7253791], dtype=float32),
#  array([1.7565572], dtype=float32),
#  array([1.7870536], dtype=float32),
#  array([1.8143672], dtype=float32),
#  array([2.812755], dtype=float32),
#  array([3.6193788], dtype=float32),
#  array([3.0384116], dtype=float32),
#  array([3.4667711], dtype=float32),
#  array([0.5078193], dtype=float32),
#  array([0.48131818], dtype=float32),
#  array([3.1576102], dtype=float32),
#  array([2.0588224], dtype=float32),
#  array([3.50948], dtype=float32),
#  array([0.8398485], dtype=float32),
#  array([1.1426232], dtype=float32),
#  array([1.8305814], dtype=float32),
#  array([1.8549124], dtype=float32),
#  array([1.7579192], dtype=float32),
#  array([1.3431435], dtype=float32),
#  array([2.2109442], dtype=float32),
#  array([2.9149637], dtype=float32),
#  array([2.6179852], dtype=float32),
#  array([1.0687021], dtype=float32),
#  array([1.2878672], dtype=float32),
#  array([1.5286326], dtype=float32),
#  array([1.4379375], dtype=float32),
#  array([1.3248546], dtype=float32),
#  array([0.9287029], dtype=float32),
#  array([1.8569697], dtype=float32),
#  array([1.8816683], dtype=float32),
#  array([2.7991228], dtype=float32),
#  array([0.6918735], dtype=float32),
#  array([1.639583], dtype=float32),
#  array([1.5908079], dtype=float32),
#  array([1.0150199], dtype=float32),
#  array([1.8513379], dtype=float32),
#  array([1.9405073], dtype=float32),
#  array([1.9352299], dtype=float32),
#  array([3.2619371], dtype=float32),
#  array([2.2445912], dtype=float32),
#  array([0.80515563], dtype=float32),
#  array([1.179943], dtype=float32),
#  array([5.5207553], dtype=float32),
#  array([2.9579124], dtype=float32),
#  array([3.1550536], dtype=float32),
#  array([2.6148908], dtype=float32),
#  array([1.8028705], dtype=float32),
#  array([0.9480429], dtype=float32),
#  array([1.1830816], dtype=float32),
#  array([1.8470488], dtype=float32),
#  array([2.0473154], dtype=float32),
#  array([2.0067234], dtype=float32),
#  array([1.5105877], dtype=float32),
#  array([1.9476224], dtype=float32),
#  array([1.8964816], dtype=float32),
#  array([2.8920517], dtype=float32),
#  array([1.0029207], dtype=float32),
#  array([1.0290459], dtype=float32),
#  array([0.63763666], dtype=float32),
#  array([1.2995135], dtype=float32),
#  array([2.2993999], dtype=float32),
#  array([2.2443273], dtype=float32),
#  array([1.6402228], dtype=float32),
#  array([1.2339673], dtype=float32),
#  array([1.0392597], dtype=float32),
#  array([0.5744459], dtype=float32),
#  array([0.6196136], dtype=float32),
#  array([3.9248514], dtype=float32),
#  array([1.9071255], dtype=float32),
#  array([5.2651005], dtype=float32),
#  array([3.3472524], dtype=float32),
#  array([2.5216146], dtype=float32),
#  array([0.9475655], dtype=float32),
#  array([2.0682383], dtype=float32),
#  array([2.2068212], dtype=float32),
#  array([1.8377542], dtype=float32),
#  array([1.2113273], dtype=float32),
#  array([3.629233], dtype=float32),
#  array([1.6956888], dtype=float32),
#  array([2.7291615], dtype=float32),
#  array([2.8819747], dtype=float32),
#  array([1.5147172], dtype=float32),
#  array([2.8582256], dtype=float32),
#  array([1.7306364], dtype=float32),
#  array([1.6457188], dtype=float32),
#  array([0.74043876], dtype=float32),
#  array([0.7416133], dtype=float32),
#  array([0.937894], dtype=float32),
#  array([1.5808288], dtype=float32),
#  array([1.3032559], dtype=float32),
#  array([0.8605607], dtype=float32),
#  array([0.72126865], dtype=float32),
#  array([1.5462501], dtype=float32),
#  array([0.43164432], dtype=float32),
#  array([2.010652], dtype=float32),
#  array([1.5910763], dtype=float32),
#  array([2.3484588], dtype=float32),
#  array([1.9980001], dtype=float32),
#  array([2.7948153], dtype=float32),
#  array([2.281826], dtype=float32),
#  array([1.6703992], dtype=float32),
#  array([2.7213593], dtype=float32),
#  array([1.8061879], dtype=float32),
#  array([3.5587664], dtype=float32),
#  array([0.91634554], dtype=float32),
#  array([1.1662695], dtype=float32),
#  array([4.8658547], dtype=float32),
#  array([5.1510825], dtype=float32),
#  array([1.6787319], dtype=float32),
#  array([0.61717916], dtype=float32),
#  array([2.8532295], dtype=float32),
#  array([4.353171], dtype=float32),
#  array([1.5875802], dtype=float32),
#  array([4.0414143], dtype=float32),
#  array([0.7938974], dtype=float32),
#  array([1.8861198], dtype=float32),
#  array([2.8969631], dtype=float32),
#  array([2.302484], dtype=float32),
#  array([1.7816781], dtype=float32),
#  array([2.299109], dtype=float32),
#  array([1.8256795], dtype=float32),
#  array([1.8597317], dtype=float32),
#  array([1.7759643], dtype=float32),
#  array([1.6929665], dtype=float32),
#  array([2.2248306], dtype=float32),
#  array([0.8110511], dtype=float32),
#  array([1.0083914], dtype=float32),
#  array([0.8940879], dtype=float32),
#  array([2.1557436], dtype=float32),
#  array([0.6503059], dtype=float32),
#  array([1.8252658], dtype=float32),
#  array([1.7502334], dtype=float32),
#  array([2.8469892], dtype=float32),
#  array([1.3476689], dtype=float32),
#  array([1.0660369], dtype=float32),
#  array([2.07651], dtype=float32),
#  array([4.55827], dtype=float32),
#  array([2.1080794], dtype=float32),
#  array([2.1444545], dtype=float32),
#  array([2.688324], dtype=float32),
#  array([1.465755], dtype=float32),
#  array([1.985961], dtype=float32),
#  array([3.4792552], dtype=float32),
#  array([3.124896], dtype=float32),
#  array([2.7180233], dtype=float32),
#  array([1.794249], dtype=float32),
#  array([1.2653601], dtype=float32),
#  array([1.3646384], dtype=float32),
#  array([2.2143865], dtype=float32),
#  array([2.7873402], dtype=float32),
#  array([2.5366168], dtype=float32),
#  array([2.2046204], dtype=float32),
#  array([0.98435575], dtype=float32),
#  array([0.36037603], dtype=float32),
#  array([0.5938635], dtype=float32),
#  array([0.37131438], dtype=float32),
#  array([0.58926606], dtype=float32),
#  array([1.4845932], dtype=float32),
#  array([0.33549434], dtype=float32),
#  array([2.3087473], dtype=float32),
#  array([2.002338], dtype=float32),
#  array([0.9468536], dtype=float32),
#  array([1.4205093], dtype=float32),
#  array([0.8253198], dtype=float32),
#  array([0.5330852], dtype=float32),
#  array([0.6082142], dtype=float32),
#  array([1.9452982], dtype=float32),
#  array([0.77477217], dtype=float32),
#  array([1.7816015], dtype=float32),
#  array([1.5143913], dtype=float32),
#  array([1.7324435], dtype=float32),
#  array([1.6964257], dtype=float32),
#  array([2.7637787], dtype=float32),
#  array([2.802575], dtype=float32),
#  array([1.8011153], dtype=float32),
#  array([0.53147095], dtype=float32),
#  array([2.3980951], dtype=float32),
#  array([2.0229027], dtype=float32),
#  array([3.4989355], dtype=float32),
#  array([3.793712], dtype=float32),
#  array([2.1085687], dtype=float32),
#  array([0.79316944], dtype=float32),
#  array([0.8388964], dtype=float32),
#  array([1.0063108], dtype=float32),
#  array([0.94234496], dtype=float32),
#  array([0.60723203], dtype=float32),
#  array([1.1624682], dtype=float32),
#  array([1.7253255], dtype=float32),
#  array([1.7207689], dtype=float32),
#  array([0.70148325], dtype=float32),
#  array([2.4577358], dtype=float32),
#  array([1.8905742], dtype=float32),
#  array([1.4705411], dtype=float32),
#  array([1.8404982], dtype=float32),
#  array([1.2638894], dtype=float32),
#  array([0.25815398], dtype=float32),
#  array([2.0452754], dtype=float32),
#  array([1.9806626], dtype=float32),
#  array([1.6879449], dtype=float32),
#  array([2.4386601], dtype=float32),
#  array([1.1931859], dtype=float32),
#  array([0.61143905], dtype=float32),
#  array([1.4911896], dtype=float32),
#  array([1.0387647], dtype=float32),
#  array([1.3501422], dtype=float32),
#  array([1.6625731], dtype=float32),
#  array([0.97623044], dtype=float32),
#  array([2.7260656], dtype=float32),
#  array([1.8940442], dtype=float32),
#  array([1.9522736], dtype=float32),
#  array([1.3058363], dtype=float32),
#  array([1.536293], dtype=float32),
#  array([2.506997], dtype=float32),
#  array([1.5196488], dtype=float32),
#  array([1.1671377], dtype=float32),
#  array([0.41594177], dtype=float32),
#  array([0.7260302], dtype=float32),
#  array([0.44332445], dtype=float32),
#  array([1.2599022], dtype=float32),
#  array([0.46436387], dtype=float32),
#  array([1.215904], dtype=float32),
#  array([1.4358437], dtype=float32),
#  array([0.6277475], dtype=float32),
#  array([0.6881675], dtype=float32),
#  array([0.87133354], dtype=float32),
#  array([1.1344455], dtype=float32),
#  array([1.5974007], dtype=float32),
#  array([1.6200004], dtype=float32),
#  array([0.82800597], dtype=float32),
#  array([1.8556459], dtype=float32),
#  array([1.0845985], dtype=float32),
#  array([0.97694045], dtype=float32),
#  array([0.16024075], dtype=float32),
#  array([0.5514381], dtype=float32),
#  array([0.98767453], dtype=float32),
#  array([0.4200831], dtype=float32),
#  array([0.9528289], dtype=float32),
#  array([0.75987715], dtype=float32),
#  array([0.47201505], dtype=float32),
#  array([0.52694005], dtype=float32),
#  array([1.4335761], dtype=float32),
#  array([1.1085256], dtype=float32),
#  array([0.53845906], dtype=float32),
#  array([0.30794242], dtype=float32),
#  array([0.43906105], dtype=float32),
#  array([1.0793518], dtype=float32),
#  array([0.3439017], dtype=float32),
#  array([0.1234972], dtype=float32),
#  array([0.33694515], dtype=float32),
#  array([1.0771345], dtype=float32),
#  array([1.847722], dtype=float32),
#  array([0.50462353], dtype=float32),
#  array([1.3489416], dtype=float32),
#  array([0.59490085], dtype=float32),
#  array([0.5211665], dtype=float32),
#  array([2.311557], dtype=float32),
#  array([1.0375648], dtype=float32),
#  array([0.84302086], dtype=float32),
#  array([0.7475422], dtype=float32),
#  array([2.0134094], dtype=float32),
#  array([2.0815282], dtype=float32),
#  array([1.0250252], dtype=float32),
#  array([0.17743066], dtype=float32),
#  array([0.9428521], dtype=float32),
#  array([1.4812932], dtype=float32),
#  array([0.94638556], dtype=float32),
#  array([0.97555816], dtype=float32),
#  array([0.27502137], dtype=float32),
#  array([1.7006505], dtype=float32),
#  array([2.3329377], dtype=float32),
#  array([1.2830048], dtype=float32),
#  array([0.33559126], dtype=float32),
#  array([0.7329162], dtype=float32),
#  array([0.62859553], dtype=float32),
#  array([0.39075905], dtype=float32),
#  array([0.701444], dtype=float32),
#  array([1.112263], dtype=float32),
#  array([1.1244485], dtype=float32),
#  array([0.6670156], dtype=float32),
#  array([0.14661123], dtype=float32),
#  array([1.3683698], dtype=float32),
#  array([1.1875217], dtype=float32),
#  array([1.176303], dtype=float32),
#  array([0.8721008], dtype=float32),
#  array([0.6289042], dtype=float32),
#  array([2.1433396], dtype=float32),
#  array([1.6587884], dtype=float32),
#  array([0.43552905], dtype=float32),
#  array([0.3368179], dtype=float32),
#  array([1.229865], dtype=float32),
#  array([2.7082033], dtype=float32),
#  array([1.5623692], dtype=float32),
#  array([1.7832782], dtype=float32),
#  array([1.322701], dtype=float32),
#  array([2.3530402], dtype=float32),
#  array([1.1040401], dtype=float32),
#  array([1.2644659], dtype=float32),
#  array([0.96427995], dtype=float32),
#  array([0.23975359], dtype=float32),
#  array([0.6801587], dtype=float32),
#  array([0.65362424], dtype=float32),
#  array([0.6494342], dtype=float32),
#  array([0.61923], dtype=float32),
#  array([0.53251934], dtype=float32),
#  array([0.8097803], dtype=float32),
#  array([0.65668076], dtype=float32),
#  array([0.74846214], dtype=float32),
#  array([0.73683506], dtype=float32),
#  array([0.67792064], dtype=float32),
#  array([0.47409493], dtype=float32),
#  array([0.6541694], dtype=float32),
#  array([1.627384], dtype=float32),
#  array([1.7577567], dtype=float32),
#  array([1.7237079], dtype=float32),
#  array([1.9783487], dtype=float32),
#  array([1.3457358], dtype=float32),
#  array([1.1188287], dtype=float32),
#  array([0.92855686], dtype=float32),
#  array([0.641236], dtype=float32),
#  array([1.6220186], dtype=float32),
#  array([0.9570566], dtype=float32),
#  array([0.54237115], dtype=float32),
#  array([3.8633585], dtype=float32),
#  array([1.8120046], dtype=float32),
#  array([2.430142], dtype=float32),
#  array([2.2143455], dtype=float32),
#  array([0.914355], dtype=float32),
#  array([2.953377], dtype=float32),
#  array([2.227248], dtype=float32),
#  array([0.7046509], dtype=float32),
#  array([0.4774595], dtype=float32),
#  array([1.9396044], dtype=float32),
#  array([5.8090224], dtype=float32),
#  array([2.2384887], dtype=float32),
#  array([2.2370143], dtype=float32),
#  array([3.7113261], dtype=float32),
#  array([2.8519769], dtype=float32),
#  array([2.3842125], dtype=float32),
#  array([1.5541763], dtype=float32),
#  array([5.20993], dtype=float32),
#  array([2.1602793], dtype=float32),
#  array([2.2463737], dtype=float32),
#  array([2.8612823], dtype=float32),
#  array([1.7910926], dtype=float32),
#  array([3.305076], dtype=float32),
#  array([2.1316273], dtype=float32),
#  array([3.2786655], dtype=float32),
#  array([0.9996672], dtype=float32),
#  array([2.0164356], dtype=float32),
#  array([2.2937198], dtype=float32),
#  array([2.2238674], dtype=float32),
#  array([3.2045627], dtype=float32),
#  array([0.6756174], dtype=float32),
#  array([0.33952594], dtype=float32),
#  array([0.75445986], dtype=float32),
#  array([1.5275874], dtype=float32),
#  array([0.43685806], dtype=float32),
#  array([0.22153156], dtype=float32),
#  array([0.1798758], dtype=float32),
#  array([0.93094456], dtype=float32),
#  array([1.0026848], dtype=float32),
#  array([1.9719725], dtype=float32),
#  array([3.2113824], dtype=float32),
#  array([2.003378], dtype=float32),
#  array([2.0085418], dtype=float32),
#  array([4.3237033], dtype=float32),
#  array([4.328867], dtype=float32),
#  array([2.92098], dtype=float32),
#  array([2.7952633], dtype=float32),
#  array([0.45666778], dtype=float32),
#  array([1.0981605], dtype=float32),
#  array([3.741377], dtype=float32),
#  array([2.5457652], dtype=float32),
#  array([3.1390367], dtype=float32),
#  array([3.4730916], dtype=float32),
#  array([2.635873], dtype=float32),
#  array([0.7874635], dtype=float32),
#  array([0.9958287], dtype=float32),
#  array([1.0854801], dtype=float32),
#  array([0.84422284], dtype=float32),
#  array([1.8441074], dtype=float32),
#  array([3.0528288], dtype=float32),
#  array([3.6470284], dtype=float32),
#  array([0.6798367], dtype=float32),
#  array([0.99148196], dtype=float32),
#  array([3.6281567], dtype=float32),
#  array([3.5011911], dtype=float32),
#  array([0.79243875], dtype=float32),
#  array([0.67625034], dtype=float32),
#  array([0.8184307], dtype=float32),
#  array([4.7115254], dtype=float32),
#  array([4.204758], dtype=float32),
#  array([3.3804681], dtype=float32),
#  array([3.8590353], dtype=float32),
#  array([2.0666165], dtype=float32),
#  array([4.615557], dtype=float32),
#  array([2.4491217], dtype=float32),
#  array([2.078525], dtype=float32),
#  array([2.24978], dtype=float32),
#  array([3.2787654], dtype=float32),
#  array([2.6971028], dtype=float32),
#  array([1.7251341], dtype=float32),
#  array([0.5301046], dtype=float32),
#  array([2.188272], dtype=float32),
#  array([1.8339317], dtype=float32),
#  array([1.9995308], dtype=float32),
#  array([1.9242586], dtype=float32),
#  array([2.5139256], dtype=float32),
#  array([0.4558741], dtype=float32),
#  array([0.79572374], dtype=float32),
#  array([1.1504619], dtype=float32),
#  array([1.1589371], dtype=float32),
#  array([1.9503906], dtype=float32),
#  array([1.2644086], dtype=float32),
#  array([2.2178152], dtype=float32),
#  array([1.9289407], dtype=float32),
#  array([0.40550074], dtype=float32),
#  array([0.54012924], dtype=float32),
#  array([1.0293424], dtype=float32),
#  array([2.3134367], dtype=float32),
#  array([2.7491553], dtype=float32),
#  array([3.6356306], dtype=float32),
#  array([0.8869687], dtype=float32),
#  array([0.60570586], dtype=float32),
#  array([0.7465859], dtype=float32),
#  array([6.905733], dtype=float32),
#  array([4.5699005], dtype=float32),
#  array([3.2760105], dtype=float32),
#  array([4.604928], dtype=float32),
#  array([1.6695479], dtype=float32),
#  array([0.99725074], dtype=float32),
#  array([0.4454203], dtype=float32),
#  array([2.6500595], dtype=float32),
#  array([2.2588444], dtype=float32),
#  array([2.1986437], dtype=float32),
#  array([1.2657281], dtype=float32),
#  array([3.3465137], dtype=float32),
#  array([3.2811406], dtype=float32),
#  array([2.448038], dtype=float32),
#  array([0.32363418], dtype=float32),
#  array([0.5134682], dtype=float32),
#  array([2.2789056], dtype=float32),
#  array([1.4965856], dtype=float32),
#  array([1.2061005], dtype=float32),
#  array([1.1705582], dtype=float32),
#  array([2.5075145], dtype=float32),
#  array([1.6309696], dtype=float32),
#  array([1.1792531], dtype=float32),
#  array([0.97072005], dtype=float32),
#  array([0.8434077], dtype=float32),
#  array([0.88695407], dtype=float32),
#  array([2.35141], dtype=float32),
#  array([2.1370761], dtype=float32),
#  array([1.9735898], dtype=float32),
#  array([2.0587633], dtype=float32),
#  array([1.6695595], dtype=float32),
#  array([4.096835], dtype=float32),
#  array([3.855291], dtype=float32),
#  array([4.0596576], dtype=float32),
#  array([3.435141], dtype=float32),
#  array([1.3639429], dtype=float32),
#  array([0.42525703], dtype=float32),
#  array([3.8499515], dtype=float32),
#  array([3.642743], dtype=float32),
#  array([4.3601317], dtype=float32),
#  array([1.0873166], dtype=float32),
#  array([3.8959303], dtype=float32),
#  array([4.220141], dtype=float32),
#  array([3.8194776], dtype=float32),
#  array([2.122723], dtype=float32),
#  array([1.8463714], dtype=float32),
#  array([0.6303221], dtype=float32),
#  array([2.1202495], dtype=float32),
#  array([4.2521987], dtype=float32),
#  array([4.9654813], dtype=float32),
#  array([1.5197077], dtype=float32),
#  array([0.9308249], dtype=float32),
#  array([2.5698416], dtype=float32),
#  array([2.301917], dtype=float32),
#  array([4.1191483], dtype=float32),
#  array([3.6111193], dtype=float32),
#  array([2.115156], dtype=float32),
#  array([1.1367271], dtype=float32),
#  array([0.756195], dtype=float32),
#  array([1.2647626], dtype=float32),
#  array([1.2422442], dtype=float32),
#  array([1.737173], dtype=float32),
#  array([2.1160533], dtype=float32),
#  array([1.2182701], dtype=float32),
#  array([0.6345644], dtype=float32),
#  array([3.9533978], dtype=float32),
#  array([4.3625956], dtype=float32),
#  array([3.3771594], dtype=float32),
#  array([4.054186], dtype=float32),
#  array([6.643869], dtype=float32),
#  array([1.3229642], dtype=float32),
#  array([0.56650573], dtype=float32),
#  array([4.592903], dtype=float32),
#  array([5.125075], dtype=float32),
#  array([3.1231813], dtype=float32),
#  array([2.8624449], dtype=float32),
#  array([2.5706134], dtype=float32),
#  array([0.7058794], dtype=float32),
#  array([4.30014], dtype=float32),
#  array([3.4167414], dtype=float32),
#  array([3.9185658], dtype=float32),
#  array([4.600182], dtype=float32),
#  array([2.364842], dtype=float32),
#  array([1.0916284], dtype=float32),
#  array([3.7348971], dtype=float32),
#  array([2.7842126], dtype=float32),
#  array([3.1303158], dtype=float32),
#  array([6.188358], dtype=float32),
#  array([6.2545304], dtype=float32),
#  array([2.293284], dtype=float32),
#  array([0.9357854], dtype=float32),
#  array([2.3180768], dtype=float32),
#  array([5.4582], dtype=float32),
#  array([3.441634], dtype=float32),
#  array([1.9791274], dtype=float32),
#  array([1.6997588], dtype=float32),
#  array([1.8427489], dtype=float32),
#  array([3.7844687], dtype=float32),
#  array([2.7757988], dtype=float32),
#  array([2.288386], dtype=float32),
#  array([1.4123814], dtype=float32),
#  array([1.3865219], dtype=float32),
#  array([1.2086823], dtype=float32),
#  array([1.4521222], dtype=float32),
#  ...]

# %% [markdown]
# The model gave us a result string y. I am now processing this result string into a list.

# %%
import numpy as np

conc = np.vstack(predictions)
conc
# Out:
# array([[2.2904341],
#        [1.4195127],
#        [0.9917113],
#        ...,
#        [1.2040666],
#        [0.4435346],
#        [3.111309 ]], dtype=float32)

# %%
ZHP = pd.DataFrame(conc)
ZHP.rename(columns={0:'y_pred'}, inplace=True)

kot = ZHP['y_pred'].values
kot = kot.astype('float32')
kot.dtype
# Out:
# dtype('float32')

# %% [markdown]
# Now I'm creating a list of real y values from the test set.

# %%
y = df_test['CO_GT'].values
y = y.astype('float32')
y.dtype
# Out:
# dtype('float32')

# %% [markdown]
# Now I create a dataframe with y-real and y-predicted variables.

# %%
PZU = pd.DataFrame({'y': y, 'y_pred': kot })
PZU.dtypes
# Out:
# y         float64
# y_pred    float64
# dtype: object

# %% [markdown]
# https://stackoverflow.com/questions/42351184/how-to-calculate-r2-in-tensorflow

# %%
def R_squared(y, y_pred):
    
  residual = tf.reduce_sum(tf.square(tf.subtract(y,y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.div(residual, total))
  return r2

# %% [markdown]
# https://blog.minitab.com/blog/adventures-in-statistics-2/regression-analysis-how-do-i-interpret-r-squared-and-assess-the-goodness-of-fit

# %% [markdown]
# To use this function, both variables must have the same data type.

# %%
y.dtype
# Out:
# dtype('float32')

# %%
kot.dtype
# Out:
# dtype('float32')

# %%
residual = tf.reduce_sum(tf.square(tf.subtract(y,kot)))

# %%
total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))

# %%
r2 = tf.subtract(1.0, tf.div(residual, total))

# %%
r2
# Out:
# <tf.Tensor 'Sub_27:0' shape=() dtype=float32>

# %%
sess = tf.Session()
a = sess.run(r2)
print('R Square parameter: ',a)
# Out:
# R Square parameter:  0.90320766

# %% [markdown]
# # <span style="color:#4c1130">Calculation of R Square parameter using Pandas</span>

# %%
PZU.head(5)
# Out:
#      y    y_pred
# 0  2.2  2.290434
# 1  1.2  1.419513
# 2  1.0  0.991711
# 3  1.5  1.413460
# 4  1.6  1.471673

# %%
PZU['SSE'] = (PZU['y'] - PZU['y_pred'])**2
PZU.head(3)
# Out:
#      y    y_pred       SSE
# 0  2.2  2.290434  0.008178
# 1  1.2  1.419513  0.048186
# 2  1.0  0.991711  0.000069

# %% [markdown]
# ### <span style="color:darkgreen">Point 2. We calculate the average empirical value of y</span>

# %%
PZU['ave_y'] = PZU['y'].mean()
PZU.head(3)
# Out:
#      y    y_pred       SSE     ave_y
# 0  2.2  2.290434  0.008178  2.061304
# 1  1.2  1.419513  0.048186  2.061304
# 2  1.0  0.991711  0.000069  2.061304

# %% [markdown]
# ### <span style="color:darkgreen">Point 3. We calculate the difference between empirical values y and the average of empirical values y</span>

# %%
PZU['SST'] = (PZU['y'] - PZU['ave_y'])**2
PZU.head(3)
# Out:
#      y    y_pred       SSE     ave_y       SST
# 0  2.2  2.290434  0.008178  2.061304  0.019237
# 1  1.2  1.419513  0.048186  2.061304  0.741845
# 2  1.0  0.991711  0.000069  2.061304  1.126366

# %% [markdown]
# ### <span style="color:darkgreen">Point 4. We calculate the difference between sum of SST and sum of SSE</span>

# %%
Sum_SST = PZU['SST'].sum()
print('Sum_SST :',Sum_SST)
Sum_SSE = PZU['SSE'].sum()
print('Sum_SSE :',Sum_SSE)
SSR = Sum_SST - Sum_SSE
# Out:
# Sum_SST : 3659.9984179583107
# Sum_SSE : 354.26016629427124

# %% [markdown]
# ### <span style="color:darkgreen">Point 5. We calculate the R Square parameter</span>

# %%
r2 = SSR/Sum_SST
print('R Square parameter: ',r2)
# Out:
# R Square parameter:  0.903207562998923
